# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./hearing_test.csv")

# %%
print(df)
# Out:
#        age  physical_score  test_result
# 0     33.0            40.7            1
# 1     50.0            37.2            1
# 2     52.0            24.7            0
# 3     56.0            31.0            0
# 4     35.0            42.9            1
# ...    ...             ...          ...
# 4995  73.0             3.9            0
# 4996  57.0            33.9            1
# 4997  49.0            34.5            1
# 4998  38.0            46.4            1
# 4999  48.0            38.5            1
#
# [5000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['age', 'physical_score', 'test_result'], dtype='object')

# %%
df.head()
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %%
df.tail()
# Out:
#        age  physical_score  test_result
# 4995  73.0             3.9            0
# 4996  57.0            33.9            1
# 4997  49.0            34.5            1
# 4998  38.0            46.4            1
# 4999  48.0            38.5            1

# %%
df.head(8)
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1
# 5  58.0            23.0            0
# 6  66.0            28.9            0
# 7  38.0            41.1            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             5000 non-null   float64
#  1   physical_score  5000 non-null   float64
#  2   test_result     5000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 117.3 KB

# %%
df.columns
# Out:
# Index(['age', 'physical_score', 'test_result'], dtype='object')

# %%
plt.plot(df['physical_score'],df['age'])
plt.xlabel("physical_score")
plt.ylabel("age")
plt.title("physical_score Vs age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['test_result'],df['age'])
plt.xlabel("test_result")
plt.ylabel("age")
plt.title("test_result Vs age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['test_result'],df['age'])
plt.xlabel("age")
plt.ylabel("test_result")
plt.title("age Vs test_result")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
]
