# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#          RnD  Administration  Marketing       State     Profit
# 0  165349.20       136897.80  471784.10    New York  192261.83
# 1  162597.70       151377.59  443898.53  California  191792.06
# 2  153441.51       101145.55  407934.54     Florida  191050.39
# 3  144372.41       118671.85  383199.62    New York  182901.99
# 4  142107.34        91391.77  366168.42     Florida  166187.94

# %%
df.columns
# Out:
# Index(['RnD', 'Administration', 'Marketing', 'State', 'Profit'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RnD             50 non-null     float64
#  1   Administration  50 non-null     float64
#  2   Marketing       50 non-null     float64
#  3   State           50 non-null     object
#  4   Profit          50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isna().sum()
# Out:
# RnD               0
# Administration    0
# Marketing         0
# State             0
# Profit            0
# dtype: int64

# %%
covariance_value1 = np.cov(df['RnD'],df['Profit'])
covariance_value2 = np.cov(df['Administration'],df['Profit'])
covariance_value3 = np.cov(df['Marketing'],df['Profit'])

print(f"RnD and Profit = {covariance_value1[0][1]}")
print(f"Administration and Profit = {covariance_value2[0][1]}")
print(f"Marketing and Profit = {covariance_value3[0][1]}")
# Out:
# RnD and Profit = 1800006569.8082128
# Administration and Profit = 226667335.92315874
# Marketing and Profit = 3685778607.116116

# %%
correlation_value1 = np.corrcoef(df['RnD'],df['Profit'])
correlation_value2 = np.corrcoef(df['Administration'],df['Profit'])
correlation_value3 = np.corrcoef(df['Marketing'],df['Profit'])

print(f"RnD and Profit = {correlation_value1[0][1]}")
print(f"Administration and Profit = {correlation_value2[0][1]}")
print(f"Marketing and Profit = {correlation_value3[0][1]}")
# Out:
# RnD and Profit = 0.9729004656594831
# Administration and Profit = 0.20071656826872128
# Marketing and Profit = 0.7477657217414766

# %%
plt.plot(df['RnD'],df['Profit'])
plt.xlabel("RnD")
plt.ylabel("Profit")
plt.title("RnD Vs Profit")
# Out:
# Text(0.5, 1.0, 'RnD Vs Profit')

# %%
plt.plot(df['Administration'],df['Profit'])
plt.xlabel("Administration")
plt.ylabel("Profit")
plt.title("Administration Vs Profit")
# Out:
# Text(0.5, 1.0, 'Administration Vs Profit')

# %%
plt.plot(df['Marketing'],df['Profit'])
plt.xlabel("Marketing")
plt.ylabel("Profit")
plt.title("Marketing Vs Profit")
plt.savefig("Marketing_Profit")

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RnD             50 non-null     float64
#  1   Administration  50 non-null     float64
#  2   Marketing       50 non-null     float64
#  3   State           50 non-null     object
#  4   Profit          50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df['State']
# Out:
# 0       New York
# 1     California
# 2        Florida
# 3       New York
# 4        Florida
# 5       New York
# 6     California
# 7        Florida
# 8       New York
# 9     California
# 10       Florida
# 11    California
# 12       Florida
# 13    California
# 14       Florida
# 15      New York
# 16    California
# 17      New York
# 18       Florida
# 19      New York
# 20    California
# 21      New York
# 22       Florida
# 23       Florida
# 24      New York
# 25    California
# 26       Florida
# 27      New York
# 28       Florida
# 29      New York
# 30       Florida
# 31      New York
# 32    California
# 33       Florida
# 34    California
# 35      New York
# 36       Florida
# 37    California
# 38      New York
# 39    California
# 40    California
# 41       Florida
# 42    California
# 43      New York
# 44    California
# 45      New York
# 46       Florida
# 47    California
# 48      New York
# 49    California
# Name: State, dtype: object

# %%
print(df['State'].unique())
# Out:
# ['New York' 'California' 'Florida']

# %%
unique_states = df['State'].unique()

state_numbers = [1,2,3]
df.replace(unique_states,state_numbers,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RnD             50 non-null     float64
#  1   Administration  50 non-null     float64
#  2   Marketing       50 non-null     float64
#  3   State           50 non-null     int64
#  4   Profit          50 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 2.1 KB

# %%
print(df['State'].unique())
# Out:
# [1 2 3]

# %%
df.head()
# Out:
#          RnD  Administration  Marketing  State     Profit
# 0  165349.20       136897.80  471784.10      1  192261.83
# 1  162597.70       151377.59  443898.53      2  191792.06
# 2  153441.51       101145.55  407934.54      3  191050.39
# 3  144372.41       118671.85  383199.62      1  182901.99
# 4  142107.34        91391.77  366168.42      3  166187.94
